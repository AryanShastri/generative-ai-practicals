# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parameters
mean = 50
std = 10

# Generate synthetic data
data = np.random.normal(mean, std, 1000)

# PDF
x = np.linspace(10, 90, 1000)
pdf = norm.pdf(x, mean, std)

# Visualization
plt.hist(data, bins=30, density=True, alpha=0.6, label="Synthetic Data")
plt.plot(x, pdf, label="Gaussian PDF")

plt.xlabel("Value")
plt.ylabel("Density")
plt.title("Gaussian Distribution and Synthetic Data")
plt.legend()
plt.show()

# Statistics
print("Mean:", np.mean(data))
print("Standard Deviation:", np.std(data))
# Out:
# Mean: 49.9843960631514
# Standard Deviation: 10.113812571055405
