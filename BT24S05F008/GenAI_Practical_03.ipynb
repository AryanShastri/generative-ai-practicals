# %%
# !pip install -q transformers

from transformers import pipeline

generator = pipeline(
    "text-generation",
    model="gpt2"
)

prompt = "Artificial Intelligence is"

output = generator(
    prompt,
    max_new_tokens=50,
    num_return_sequences=1,
    clean_up_tokenization_spaces=False
)

print("Generated Text:")
print(output[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# [transformers] Both `max_new_tokens` (=50) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generated Text:
# Artificial Intelligence is working on the next generation of artificial intelligence, and as the technology progresses, it will likely see a change in perception-based cognition. A computer will see what people think, and it will decide what to do with that information. It will be able
