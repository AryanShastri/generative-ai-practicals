# %%
# !pip install transformers torch

# %% [markdown]
# # Practical 3: Transformer-Based Language Models and Text Generation
#
# ## Aim
#
# To study the architecture of transformer-based language models and generate text using pretrained models.
#
# ## Introduction
#
# Transformer is a deep learning architecture widely used in Natural Language Processing (NLP).
# It uses the attention mechanism to understand relationships between words in a sequence.
#
# Transformer-based language models such as GPT and BERT have achieved excellent performance in various NLP tasks.
#
# In this practical, we study the basic architecture and components of Transformer-based language models and use a pretrained GPT-2 model to generate text from a given prompt.

# %% [markdown]
# ## Transformer Architecture
#
# The Transformer architecture was introduced to process sequential data using the attention mechanism instead of relying only on recurrent neural networks.
#
# ### Main Components of Transformer
#
# 1. Self-Attention:
#    Helps the model understand the relationship between different words in a sentence.
#
# 2. Multi-Head Attention:
#    Allows the model to focus on different relationships between words simultaneously.
#
# 3. Positional Encoding:
#    Provides information about the position of words in the input sequence.
#
# 4. Feed Forward Neural Network:
#    Processes the representations generated by the attention layers.
#
# 5. Layer Normalization:
#    Helps stabilize and improve the training of the model.
#
# 6. Residual Connections:
#    Help information flow through deeper layers and make training easier.
#
# ### Transformer-based Language Models
#
# - BERT: Mainly uses the Transformer encoder and is designed for understanding text.
# - GPT: Uses the Transformer decoder architecture and is designed for autoregressive text generation.

# %%
from transformers import pipeline

print("Transformers library imported successfully!")
# Out:
# Transformers library imported successfully!

# %%
from transformers import pipeline

# Load a pretrained GPT-2 text generation model
generator = pipeline("text-generation", model="gpt2")

print("Pretrained GPT-2 model loaded successfully!")
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors: reconstructing file:   0%|          |  0.00B /  548MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Pretrained GPT-2 model loaded successfully!

# %%
# Input prompt
prompt = "Artificial Intelligence is"

# Generate text using the pretrained GPT-2 model
result = generator(
    prompt,
    max_new_tokens=50,
    num_return_sequences=1,
    clean_up_tokenization_spaces=False
)

print("Input Prompt:")
print(prompt)

print("\nGenerated Text:")
print(result[0]["generated_text"])
# Out:
# [transformers] Passing `generation_config` together with generation-related arguments=({'num_return_sequences', 'max_new_tokens'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Both `max_new_tokens` (=50) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Input Prompt:
# Artificial Intelligence is
#
# Generated Text:
# Artificial Intelligence is a new field of research aimed at helping us understand the brain, but it's also often in the wrong place at the wrong time. The problem with artificial intelligence is that it cannot understand what is happening in the real world. It cannot solve problems in

# %%
prompts = [
    "The future of technology is",
    "Machine learning is",
    "India is developing",
]

for prompt in prompts:
    result = generator(
        prompt,
        max_new_tokens=40,
        num_return_sequences=1,
        clean_up_tokenization_spaces=False
    )

    print("Prompt:", prompt)
    print("Generated Text:", result[0]["generated_text"])
    print("-" * 80)
# Out:
# [transformers] Both `max_new_tokens` (=40) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=40) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Prompt: The future of technology is
# Generated Text: The future of technology is more interesting than ever. I'm fascinated by the future of life as we know it. I'm curious about where we are in the coming decade, and how the evolution of technology will affect our lives
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## GPT-2 Architecture
#
# GPT-2 (Generative Pre-trained Transformer 2) is a Transformer-based autoregressive language model developed by OpenAI.
#
# GPT-2 uses the Transformer decoder architecture to generate text.
#
# ### Working of GPT-2
#
# 1. The input text is first converted into tokens.
# 2. Tokens are converted into numerical representations.
# 3. Positional information is added to preserve the order of tokens.
# 4. Self-attention helps the model identify relationships between tokens.
# 5. Multiple Transformer decoder blocks process the input.
# 6. The model predicts the probability of the next token.
# 7. The predicted token is added to the sequence.
# 8. This process continues until the required number of tokens is generated.
#
# ### Text Generation Flow
#
# Input Prompt
#       ↓
# Tokenization
#       ↓
# Token Embeddings + Positional Information
#       ↓
# Transformer Decoder Blocks
#       ↓
# Self-Attention
#       ↓
# Feed Forward Network
#       ↓
# Next Token Prediction
#       ↓
# Generated Text

# %% [markdown]
# ## Observation
#
# - A pretrained GPT-2 Transformer language model was successfully loaded.
# - The model accepted a text prompt as input.
# - GPT-2 generated new text based on the given prompt.
# - Different prompts produced different generated outputs.
# - The experiment demonstrates autoregressive text generation using a pretrained Transformer-based language model.

# %% [markdown]
# ## Result
#
# The architecture of Transformer-based language models was studied successfully, and text was generated using the pretrained GPT-2 model.

# %% [markdown]
# ## Conclusion
#
# In this practical, the basic architecture and important components of Transformer-based language models were studied. A pretrained GPT-2 model was successfully used to generate text from different input prompts. The practical demonstrated how Transformer-based language models can understand a sequence of tokens and generate the next tokens autoregressively.
